# %%
employees = ["RAJESH", "KUMAR", "VIJAY", "ARUN"]
print(employees)
# Out:
# ['RAJESH', 'KUMAR', 'VIJAY', 'ARUN']

# %%
employees.append("SURESH")
print(employees)
# Out:
# ['RAJESH', 'KUMAR', 'VIJAY', 'ARUN', 'SURESH', 'SURESH']

# %%
employees.remove("KUMAR")

# %%
print(employees)
# Out:
# ['RAJESH', 'VIJAY', 'ARUN', 'SURESH']

# %%
print("Total employees:", len(employees))
# Out:
# Total employees: 4

# %%
if "VIJAY" in employees:
    print("VIJAY is present")
else:
    print("VIJAY is not present")
# Out:
# VIJAY is present

# %%
employees.sort()

print("Employees:", employees)
# Out:
# Employees: ['ARUN', 'RAJESH', 'SURESH', 'VIJAY']

# %%
cart = ["Laptop", "Mouse", "Keyboard", "Headset"]

# %%
print(cart)
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Headset']

# %%
cart.append("Monitor")
print(cart)
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Headset', 'Monitor']

# %%
cart.remove("Headset")
print(cart)
# Out:
# ['Laptop', 'Mouse', 'Keyboard', 'Monitor']

# %%
print("First product:", cart[0], "And", "Last product:", cart[-1])
# Out:
# First product: Laptop And Last product: Monitor

# %%
if "Mouse" in cart:
    print("Mouse is in the cart")
else:
    print("Mouse is not in the cart")
# Out:
# Mouse is in the cart

# %%
print("Number of products:", len(cart))
# Out:
# Number of products: 4

# %%
cart.reverse()
print("Reversed cart:", cart)
# Out:
# Reversed cart: ['Monitor', 'Keyboard', 'Mouse', 'Laptop']

# %%
reversed_cart = ""
for product in cart:
    reversed_cart =  reversed_cart+" "+ product
print("Reversed cart:", reversed_cart)
# Out:
# Reversed cart:  Monitor Keyboard Mouse Laptop

# %%
marks = [85, 72, 90, 65, 88, 76, 95, 68, 82, 79]
print("Marks:", marks)
# Out:
# Marks: [85, 72, 90, 65, 88, 76, 95, 68, 82, 79]

# %%
print("Highest mark:", max(marks))
# Out:
# Highest mark: 95

# %%
Highest_mark=[0]
for mark in marks:
    if mark > Highest_mark[0]:
        Highest_mark[0] = mark
print("Highest mark:", Highest_mark[0])
# Out:
# Highest mark: 95

# %%
print("Lowest mark:", min(marks))
# Out:
# Lowest mark: 65

# %%
Lowest_mark=[0]
for mark in marks:
    if Lowest_mark[0] == 0 or mark < Lowest_mark[0]:
        Lowest_mark[0] = mark
print("Lowest mark:", Lowest_mark[0])
# Out:
# Lowest mark: 65

# %%
average = sum(marks) / len(marks)
print("Average:", average)
# Out:
# Average: 80.0

# %%
count = 0

for mark in marks:
    if mark > 75:
        count += 1

print("Students above 75:", count)
# Out:
# Students above 75: 7

# %%
marks.sort()
print("Ascending order:", marks)
# Out:
# Ascending order: [65, 68, 72, 76, 79, 82, 85, 88, 90, 95]

# %%
print("Top 3 marks:", marks[-3:])
# Out:
# Top 3 marks: [88, 90, 95]

# %%
prices = [250, 600, 150, 800, 450, 700, 300, 550]
print("Prices:", prices)
# Out:
# Prices: [250, 600, 150, 800, 450, 700, 300, 550]

# %%
prices.append(900)
print("Prices:", prices)
# Out:
# Prices: [250, 600, 150, 800, 450, 700, 300, 550, 900]

# %%
print("Maximum price:", max(prices))
# Out:
# Maximum price: 900

# %%
Maximum_price=[0]
for price in prices:
    if price > Maximum_price[0]:
        Maximum_price[0] = price
print("Maximum price:", Maximum_price[0])
# Out:
# Maximum price: 900

# %%
print("Minimum price:", min(prices))
# Out:
# Minimum price: 150

# %%
minimum_price=[0]
for price in prices:    
    if minimum_price[0] == 0 or price < minimum_price[0]:
        minimum_price[0] = price    
print("Minimum price:", minimum_price[0])
# Out:
# Minimum price: 150

# %%
total = sum(prices)
print("Total bill:", total)
# Out:
# Total bill: 4700

# %%
average = sum(prices) / len(prices)
print("Average price:", average)
# Out:
# Average price: 522.2222222222222

# %%
for i in range(len(prices)):
    prices[i] = prices[i] * 1.10

print("Prices after 10% increase:", prices)
# Out:
# Prices after 10% increase: [275.0, 660.0, 165.0, 880.0000000000001, 495.00000000000006, 770.0000000000001, 330.0, 605.0, 990.0000000000001]

# %%
print("Prices above 500:")

for price in prices:
    if price > 500:
        print(price)
# Out:
# Prices above 500:
# 660.0
# 880.0000000000001
# 770.0000000000001
# 605.0
# 990.0000000000001

# %%
downloads = [1200, 1500, 980, 2100, 1750, 2300, 1900]
print("Downloads:", downloads)
# Out:
# Downloads: [1200, 1500, 980, 2100, 1750, 2300, 1900]

# %%
highest_downloads = [0]
for download in downloads:
    if download > highest_downloads[0]:
        highest_downloads[0] = download
print("Highest downloads:", highest_downloads[0])
# Out:
# Highest downloads: 2300

# %%
highest_day = downloads.index(highest_downloads[0]) + 1
print("Highest downloads day: Day", highest_day)
# Out:
# Highest downloads day: Day 6

# %%
lowest_downloads = [0]
for download in downloads:  
    if lowest_downloads[0] == 0 or download < lowest_downloads[0]:
        lowest_downloads[0] = download
print("Lowest downloads:", lowest_downloads[0])
# Out:
# Lowest downloads: 980

# %%
lowest_day = downloads.index(lowest_downloads[0]) + 1
print("Lowest downloads day: Day", lowest_day)
# Out:
# Lowest downloads day: Day 3

# %%
print("Total downloads:", sum(downloads))
# Out:
# Total downloads: 11730

# %%
average = sum(downloads) / len(downloads)
print("Average downloads:", average)
# Out:
# Average downloads: 1675.7142857142858

# %%
count = 0

for download in downloads:
    if download > 1800:
        count += 1

print("Days above 1800:", count)
# Out:
# Days above 1800: 3

# %%
ratings = [4, 5, 3, 4, 2, 5, 4, 3, 5]
print("Ratings:", ratings)
# Out:
# Ratings: [4, 5, 3, 4, 2, 5, 4, 3, 5]

# %%
average = sum(ratings) / len(ratings)
print("Average rating:", average)
# Out:
# Average rating: 3.888888888888889

# %%
count_5 = 0

for rating in ratings:
    if rating == 5:
        count_5 += 1

print("5-star ratings:", count_5)
# Out:
# 5-star ratings: 3

# %%
count_below_3 = 0

for rating in ratings:
    if rating < 3:
        count_below_3 += 1

print("Ratings below 3:", count_below_3)
# Out:
# Ratings below 3: 1

# %%
highest_rating = [0]
for rating in ratings:
    if rating > highest_rating[0]:
        highest_rating[0] = rating  

print("Highest rating:", highest_rating[0])
# Out:
# Highest rating: 5

# %%
ratings.sort()
print("Sorted ratings:", ratings)
# Out:
# Sorted ratings: [2, 3, 3, 4, 4, 4, 5, 5, 5]

# %%
unique_ratings = list(set(ratings))
print("Unique ratings:", unique_ratings)
# Out:
# Unique ratings: [2, 3, 4, 5]

# %%
employee = (101, "Akash", "Data Analyst", 45000)

# %%
print("Employee ID:", employee[0])
# Out:
# Employee ID: 101

# %%
print("Employee name:", employee[1])
# Out:
# Employee name: Akash

# %%
print("Designation:", employee[2])
# Out:
# Designation: Data Analyst

# %%
print("Salary:", employee[3])
# Out:
# Salary: 45000

# %%
count = 0
for element in employee:
    count += 1
print("Number of elements:", count)
# Out:
# Number of elements: 4

# %%
if "Data Analyst" in employee:
    print("Data Analyst exists")
else:
    print("Data Analyst does not exist")
# Out:
# Data Analyst exists

# %%
location = ("12.9249", "80.1000")

# %%
print("Latitude:", location[0])
# Out:
# Latitude: 12.9249

# %%
print("Longitude:", location[1])
# Out:
# Longitude: 80.1000

# %%
latitude, longitude = location
print("Latitude:", latitude)
print("Longitude:", longitude)
# Out:
# Latitude: 12.9249
# Longitude: 80.1000

# %%
latitude_ = float(latitude)
if latitude_ > 12:
    print("Latitude is greater than 12")
else:
    print("Latitude is not greater than 12")
# Out:
# Latitude is greater than 12

# %%
location2 = ("13.0500", "80.2000")

# %%
if location == location2:
    print("Both locations are the same")
else:
    print("Both locations are different")
# Out:
# Both locations are different

# %%
transaction = (10025, "Credit", 15000, "Salary")

# %%
print("Transaction ID:", transaction[0])
# Out:
# Transaction ID: 10025

# %%
print("Transaction type:", transaction[1])
# Out:
# Transaction type: Credit

# %%
print("Amount:", transaction[2])
# Out:
# Amount: 15000

# %%
print("Description:", transaction[3])
# Out:
# Description: Salary

# %%
transaction_id, transaction_type, amount, description = transaction

print("Transaction ID:", transaction_id)
print("Transaction type:", transaction_type)
print("Amount:", amount)
print("Description:", description)
# Out:
# Transaction ID: 10025
# Transaction type: Credit
# Amount: 15000
# Description: Salary

# %%
if transaction_type == "Credit":
    print("Transaction is Credit")
else:
    print("Transaction is not Credit")
# Out:
# Transaction is Credit

# %%
product = ("P101", "Laptop", 65000, "Electronics")

# %%
print("Product ID:", product[0])
print("Product Name:", product[1])
print("Price:", product[2])
print("Category:", product[3])
# Out:
# Product ID: P101
# Product Name: Laptop
# Price: 65000
# Category: Electronics

# %%
product_id, product_name, price, category = product

print("Product ID:", product_id)
print("Product Name:", product_name)
print("Price:", price)
print("Category:", category)
# Out:
# Product ID: P101
# Product Name: Laptop
# Price: 65000
# Category: Electronics

# %%
count = 0
for element in product:
    count += 1
print("Number of elements:", count)
# Out:
# Number of elements: 4

# %%
if "Electronics" in product:
    print("Electronics exists")
else:
    print("Electronics does not exist")
# Out:
# Electronics exists

# %%
product2 = ("P102", "Mouse", 1500, "Electronics")

print("Second product:", product2)
# Out:
# Second product: ('P102', 'Mouse', 1500, 'Electronics')

# %%
orders = [(101, "Laptop", 65000),
    (102, "Mouse", 1200),
    (103, "Keyboard", 2500),
    (104, "Monitor", 18000)]

# %%
print("Order IDs:")

for order in orders:
    print(order[0])
# Out:
# Order IDs:
# 101
# 102
# 103
# 104

# %%
print("Product names:")

for order in orders:
    print(order[1])
# Out:
# Product names:
# Laptop
# Mouse
# Keyboard
# Monitor

# %%
total = 0

for order in orders:
    total += order[2]

print("Total order value:", total)
# Out:
# Total order value: 86700

# %%
most_expensive = orders[0]

for order in orders:
    if order[2] > most_expensive[2]:
        most_expensive = order

print("Most expensive order:", most_expensive)
# Out:
# Most expensive order: (101, 'Laptop', 65000)

# %%
print("Orders above 10000:")

for order in orders:
    if order[2] > 10000:
        print(order)
# Out:
# Orders above 10000:
# (101, 'Laptop', 65000)
# (104, 'Monitor', 18000)

# %%
students = [(101, "Arun", 85),(102, "Priya", 92),(103, "Kavin", 76),(104, "Meena", 88)]

# %%
print("Student names:")

for student in students:
    print(student[1])




highest = students[0]

for student in students:
    if student[2] > highest[2]:
        highest = student

print("Highest mark student:", highest)




total = 0

for student in students:
    total += student[2]

average = total / len(students)

print("Average mark:", average)




print("Students above 80:")

for student in students:
    if student[2] > 80:
        print(student)




students.append((105, "Suresh", 90))

print("After adding new student:")
print(students)




student_id = 103

for student in students:
    if student[0] == student_id:
        students.remove(student)
        break

print("After removing student 103:")
print(students)
# Out:
# Student names:
# Arun
# Priya
# Kavin
# Meena
#
# Highest mark student: (102, 'Priya', 92)
# Average mark: 85.25
#
# Students above 80:
# (101, 'Arun', 85)
# (102, 'Priya', 92)
# (104, 'Meena', 88)
#
# After adding new student:
# [(101, 'Arun', 85), (102, 'Priya', 92), (103, 'Kavin', 76), (104, 'Meena', 88), (105, 'Suresh', 90)]
#
# After removing student 103:
# [(101, 'Arun', 85), (102, 'Priya', 92), (104, 'Meena', 88), (105, 'Suresh', 90)]

# %%
patients = [(1, "Rahul", 45, "Fever"),(2, "Priya", 32, "Diabetes"),(3, "Arun", 60, "Fever"),(4, "Meena", 28, "Cold")]

# %%
print("Patient names:")

for patient in patients:
    print(patient[1])




print("Patients with Fever:")

for patient in patients:
    if patient[3] == "Fever":
        print(patient)




oldest = patients[0]

for patient in patients:
    if patient[2] > oldest[2]:
        oldest = patient

print("Oldest patient:", oldest)





count = 0

for patient in patients:
    if patient[2] > 40:
        count += 1

print("Patients above 40:", count)






patients.append((5, "Kumar", 50, "Cold"))

print("After adding patient:")
print(patients)





patient_id = 2

for patient in patients:
    if patient[0] == patient_id:
        patients.remove(patient)
        break

print("After removing patient 2:")
print(patients)
# Out:
# Patient names:
# Rahul
# Priya
# Arun
# Meena
# Patients with Fever:
# (1, 'Rahul', 45, 'Fever')
# (3, 'Arun', 60, 'Fever')
# Oldest patient: (3, 'Arun', 60, 'Fever')
# Patients above 40: 2
# After adding patient:
# [(1, 'Rahul', 45, 'Fever'), (2, 'Priya', 32, 'Diabetes'), (3, 'Arun', 60, 'Fever'), (4, 'Meena', 28, 'Cold'), (5, 'Kumar', 50, 'Cold')]
# After removing patient 2:
# [(1, 'Rahul', 45, 'Fever'), (3, 'Arun', 60, 'Fever'), (4, 'Meena', 28, 'Cold'), (5, 'Kumar', 50, 'Cold')]

# %%
orders = [(101, "Arun", "Pizza", 600),(102, "Priya", "Burger", 350),(103, "Kavin", "Biryani", 500),(104, "Meena", "Pizza", 700)]

# %%
print("All orders:")

for order in orders:
    print(order)




total = 0

for order in orders:
    total += order[3]

print("Total revenue:", total)





highest = orders[0]

for order in orders:
    if order[3] > highest[3]:
        highest = order

print("Highest-value order:", highest)





print("Orders above 500:")

for order in orders:
    if order[3] > 500:
        print(order)







customer = input("Enter customer name: ")

print("Orders by", customer, ":")

for order in orders:
    if order[1] == customer:
        print(order)




Number_of_orders=0
for order in orders:
    Number_of_orders += 1

print("Number of orders:", Number_of_orders)
# Out:
# All orders:
# (101, 'Arun', 'Pizza', 600)
# (102, 'Priya', 'Burger', 350)
# (103, 'Kavin', 'Biryani', 500)
# (104, 'Meena', 'Pizza', 700)
#
# Total revenue: 2150
# Highest-value order: (104, 'Meena', 'Pizza', 700)
#
# Orders above 500:
# (101, 'Arun', 'Pizza', 600)
# (104, 'Meena', 'Pizza', 700)
# Orders by Arun :
# (101, 'Arun', 'Pizza', 600)
# Number of orders: 4

# %%
reservations = [(1, "Arun", 25, "Chennai"),(2, "Priya", 32, "Madurai"),(3, "Kavin", 55, "Chennai"),(4, "Meena", 48, "Coimbatore")]

# %%
print("All passengers:")

for passenger in reservations:
    print(passenger)




destination = input("Enter destination: ")

print("Passengers travelling to", destination, ":")

for passenger in reservations:
    if passenger[3] == destination:
        print(passenger)





count = 0

for passenger in reservations:
    if passenger[2] > 50:
        count += 1

print("Passengers above 50:", count)






name = input("Enter passenger name: ")

for passenger in reservations:
    if passenger[1] == name:
        print("Passenger found:", passenger)
        break
    else:
        print("Passenger not found")
        break





new_reservation = (5, "Suresh", 40, "Trichy")
reservations.append(new_reservation)

print("After adding reservation:")
print(reservations)






seat_number = 2

for passenger in reservations:
    if passenger[0] == seat_number:
        reservations.remove(passenger)
        break

print("After cancelling seat", seat_number, ":")
print(reservations)
# Out:
# All passengers:
# (1, 'Arun', 25, 'Chennai')
# (2, 'Priya', 32, 'Madurai')
# (3, 'Kavin', 55, 'Chennai')
# (4, 'Meena', 48, 'Coimbatore')
# Passengers travelling to Chennai :
# (1, 'Arun', 25, 'Chennai')
# (3, 'Kavin', 55, 'Chennai')
# Passengers above 50: 1
# After adding reservation:
# [(1, 'Arun', 25, 'Chennai'), (2, 'Priya', 32, 'Madurai'), (3, 'Kavin', 55, 'Chennai'), (4, 'Meena', 48, 'Coimbatore'), (5, 'Suresh', 40, 'Trichy')]
# After cancelling seat 2 :
# [(1, 'Arun', 25, 'Chennai'), (3, 'Kavin', 55, 'Chennai'), (4, 'Meena', 48, 'Coimbatore'), (5, 'Suresh', 40, 'Trichy')]

# %%
products = [(101, "Laptop", 65000, 5),(102, "Mouse", 1200, 25),(103, "Keyboard", 2500, 8),(104, "Monitor", 18000, 12)]

# %%
print("Products with stock below 10:")

for product in products:
    if product[3] < 10:
        print(product)





most_expensive = products[0]

for product in products:
    if product[2] > most_expensive[2]:
        most_expensive = product

print("Most expensive product:", most_expensive)






total = 0

for product in products:
    total += product[2] * product[3]

print("Total inventory value:", total)






product_id = int(input("Enter product ID to search: "))

for product in products:
    if product[0] == product_id:
        print("Product found:", product)
        break
    else:
        print("Product not found")
        break





new_product = (105, "Headphones", 3000, 15)
products.append(new_product)

print("After adding new product:")
print(products)
# Out:
# Products with stock below 10:
# (101, 'Laptop', 65000, 5)
# (103, 'Keyboard', 2500, 8)
# Most expensive product: (101, 'Laptop', 65000, 5)
# Total inventory value: 591000
# Product not found
# After adding new product:
# [(101, 'Laptop', 65000, 5), (102, 'Mouse', 1200, 25), (103, 'Keyboard', 2500, 8), (104, 'Monitor', 18000, 12), (105, 'Headphones', 3000, 15)]
# After updating stock:
# [(101, 'Laptop', 65000, 5), (102, 'Mouse', 1200, 30), (103, 'Keyboard', 2500, 8), (104, 'Monitor', 18000, 12), (105, 'Headphones', 3000, 15)]

# %%
players = [("Virat", 15, 650, 0),("Rohit", 14, 520, 0),("Jadeja", 16, 450, 12),("Bumrah", 15, 100, 20)]

# %%
highest_runs = players[0]

for player in players:
    if player[2] > highest_runs[2]:
        highest_runs = player

print("Highest run scorer:", highest_runs)





highest_wickets = players[0]

for player in players:
    if player[3] > highest_wickets[3]:
        highest_wickets = player

print("Highest wicket taker:", highest_wickets)






print("Players with more than 500 runs:")

for player in players:
    if player[2] > 500:
        print(player)





total_runs = 0

for player in players:
    total_runs += player[2]

print("Total runs:", total_runs)





name = input("Enter player name: ")

for player in players:
    if player[0] == name:
        print("Player found:", player)
# Out:
# Highest run scorer: ('Virat', 15, 650, 0)
# Highest wicket taker: ('Bumrah', 15, 100, 20)
# Players with more than 500 runs:
# ('Virat', 15, 650, 0)
# ('Rohit', 14, 520, 0)
# Total runs: 1720
# Player found: ('Virat', 15, 650, 0)

# %%
employees = [(101, "Arun", "IT", 60000),(102, "Priya", "HR", 45000),(103, "Kavin", "IT", 75000),(104, "Meena", "Finance", 55000),(105, "Suresh", "HR", 40000)]

# %%
highest = employees[0]

for employee in employees:
    if employee[3] > highest[3]:
        highest = employee

print("Highest salary:", highest)





lowest = employees[0]

for employee in employees:
    if employee[3] < lowest[3]:
        lowest = employee

print("Lowest salary:", lowest)





total = 0

for employee in employees:
    total += employee[3]

average = total / len(employees)

print("Average salary:", average)






print("IT employees:")
for employee in employees:
    if employee[2] == "IT":
        print(employee)






print("Employees earning above 50000:")
for employee in employees:
    if employee[3] > 50000:
        print(employee)






it_count = 0
hr_count = 0
finance_count = 0

for employee in employees:
    if employee[2] == "IT":
        it_count += 1
    elif employee[2] == "HR":
        hr_count += 1
    elif employee[2] == "Finance":
        finance_count += 1

print("IT employees:", it_count)
print("HR employees:", hr_count)
print("Finance employees:", finance_count)
# Out:
# Highest salary: (103, 'Kavin', 'IT', 75000)
# Lowest salary: (105, 'Suresh', 'HR', 40000)
# Average salary: 55000.0
#
# IT employees:
# (101, 'Arun', 'IT', 60000)
# (103, 'Kavin', 'IT', 75000)
#
# Employees earning above 50000:
# (101, 'Arun', 'IT', 60000)
# (103, 'Kavin', 'IT', 75000)
# (104, 'Meena', 'Finance', 55000)
#
# IT employees: 2
# HR employees: 2
# Finance employees: 1

# %%
students = [(101, "Arun", 85, 90, 80),(102, "Priya", 92, 88, 95),(103, "Kavin", 65, 70, 75),(104, "Meena", 78, 82, 80)]

# %%
new_student = (105, "Suresh", 88, 91, 85)
students.append(new_student)





print("All students:")
for student in students:
    print(student)





print("Total and Average Marks:")

for student in students:
    total = student[2] + student[3] + student[4]
    average = total / 3

    print("Total:", total)
    print("Average:", average)





topper = students[0]

topper_total = topper[2] + topper[3] + topper[4]

for student in students:
    total = student[2] + student[3] + student[4]

    if total > topper_total:
        topper = student
        topper_total = total

print("Class topper:", topper)
print("Topper total:", topper_total)






print("Students who passed all subjects:")

for student in students:
    if student[2] >= 40 and student[3] >= 40 and student[4] >= 40:
        print(student)






student_id = 103

for student in students:
    if student[0] == student_id:
        print("Student found:", student)







highest_sub1 = students[0]
highest_sub2 = students[0]
highest_sub3 = students[0]

for student in students:

    if student[2] > highest_sub1[2]:
        highest_sub1 = student

    if student[3] > highest_sub2[3]:
        highest_sub2 = student

    if student[4] > highest_sub3[4]:
        highest_sub3 = student

print("Highest subject 1 mark:", highest_sub1[2], "-", highest_sub1[1])
print("Highest subject 2 mark:", highest_sub2[3], "-", highest_sub2[1])
print("Highest subject 3 mark:", highest_sub3[4], "-", highest_sub3[1])





print("Students with average above 80:")

for student in students:
    total = student[2] + student[3] + student[4]
    average = total / 3

    if average > 80:
        print(student[1], "Average:", average)






student_id =int(input("Enter student ID to remove: "))

for student in students:
    if student[0] == student_id:
        students.remove(student)
        break

    print(student)
