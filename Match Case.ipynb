# %%
NUMBER = int(input("ENTER A NUMBER (1-5): "))

match NUMBER:
    case 1:
        print("ONE")
    case 2:
        print("TWO")
    case 3:
        print("THREE")
    case 4:
        print("FOUR")
    case 5:
        print("FIVE")
    case _:
        print("INVALID NUMBER")
# Out:
# TWO

# %%
DAY = int(input("ENTER DAY NUMBER (1-7): "))

match DAY:
    case 1:
        print("MONDAY")
    case 2:
        print("TUESDAY")
    case 3:
        print("WEDNESDAY")
    case 4:
        print("THURSDAY")
    case 5:
        print("FRIDAY")
    case 6:
        print("SATURDAY")
    case 7:
        print("SUNDAY")
    case _:
        print("INVALID DAY")
# Out:
# THURSDAY

# %%
MONTH = int(input("ENTER MONTH NUMBER (1-12): "))

match MONTH:
    case 1:
        print("JANUARY")
    case 2:
        print("FEBRUARY")
    case 3:
        print("MARCH")
    case 4:
        print("APRIL")
    case 5:
        print("MAY")
    case 6:
        print("JUNE")
    case 7:
        print("JULY")
    case 8:
        print("AUGUST")
    case 9:
        print("SEPTEMBER")
    case 10:
        print("OCTOBER")
    case 11:
        print("NOVEMBER")
    case 12:
        print("DECEMBER")
    case _:
        print("INVALID MONTH")
# Out:
# OCTOBER

# %%
CHAR = input("ENTER A CHARACTER: ").upper()

match CHAR:
    case "A":
        print("YOU ENTERED A")
    case "B":
        print("YOU ENTERED B")
    case "C":
        print("YOU ENTERED C")
    case _:
        print("ANOTHER CHARACTER")
# Out:
# ANOTHER CHARACTER

# %%
COLOR = input("ENTER TRAFFIC SIGNAL COLOR: ").upper()

match COLOR:
    case "RED":
        print("STOP")
    case "YELLOW":
        print("WAIT")
    case "GREEN":
        print("GO")
    case _:
        print("INVALID COLOR")
# Out:
# STOP

# %%
OPTION = int(input("ENTER MENU OPTION (1-4): "))

match OPTION:
    case 1:
        print("FOOD")
    case 2:
        print("WATER")
    case 3:
        print("JUICE")
    case 4:
        print("SNACKS")
    case _:
        print("INVALID OPTION")
# Out:
# JUICE

# %%
GRADE = input("ENTER GRADE: ").upper()

match GRADE:
    case "A":
        print("EXCELLENT")
    case "B":
        print("VERY GOOD")
    case "C":
        print("GOOD")
    case "D":
        print("PASS")
    case "F":
        print("FAIL")
    case _:
        print("INVALID GRADE")
# Out:
# GOOD

# %%
SEASON = int(input("ENTER SEASON NUMBER (1-4): "))

match SEASON:
    case 1:
        print("SPRING")
    case 2:
        print("SUMMER")
    case 3:
        print("AUTUMN")
    case 4:
        print("WINTER")
    case _:
        print("INVALID SEASON")
# Out:
# INVALID SEASON

# %%
LANGUAGE = int(input("ENTER LANGUAGE CHOICE (1-3): "))

match LANGUAGE:
    case 1:
        print("PYTHON")
    case 2:
        print("JAVA")
    case 3:
        print("C++")
    case _:
        print("INVALID CHOICE")
# Out:
# PYTHON

# %%
DAY = int(input("ENTER DAY NUMBER (1-7): "))

match DAY:
    case 1 | 2 | 3 | 4 | 5:
        print("WORKING DAY")
    case 6 | 7:
        print("WEEKEND")
    case _:
        print("INVALID DAY")
# Out:
# WEEKEND

# %%
NUMBER1 = float(input("ENTER FIRST NUMBER: "))
OPERATOR = input("ENTER OPERATOR (+, -, *, /): ")
NUMBER2 = float(input("ENTER SECOND NUMBER: "))

match OPERATOR:
    case "+":
        print(F"ANSWER IS {NUMBER1 + NUMBER2}")
    case "-":
        print(F"ANSWER IS {NUMBER1 - NUMBER2}")
    case "*":
        print(F"ANSWER IS {NUMBER1 * NUMBER2}")
    case "/":
        print(F"ANSWER IS {NUMBER1 / NUMBER2}")
    case _:
        print("INVALID OPERATOR")
# Out:
# ANSWER IS 3.0

# %%
FOOD = int(input("ENTER FOOD CHOICE (1-4): "))

match FOOD:
    case 1:
        print("PIZZA - ₹200")
    case 2:
        print("BURGER - ₹150")
    case 3:
        print("SANDWICH - ₹100")
    case 4:
        print("FRIES - ₹80")
    case _:
        print("INVALID CHOICE")
# Out:
# SANDWICH - ₹100

# %%
SIZE = input("ENTER SIZE (S, M, L, XL): ").upper()

match SIZE:
    case "S":
        print("SMALL SIZE")
    case "M":
        print("MEDIUM SIZE")
    case "L":
        print("LARGE SIZE")
    case "XL":
        print("EXTRA LARGE SIZE")
    case _:
        print("INVALID SIZE")
# Out:
# MEDIUM SIZE

# %%
VEHICLE = input("ENTER VEHICLE TYPE: ").UPPER()

match VEHICLE:
    case "CAR":
        print("FOUR-WHEELER")
    case "BIKE":
        print("TWO-WHEELER")
    case "BUS":
        print("PUBLIC TRANSPORT")
    case "TRUCK":
        print("HEAVY VEHICLE")
    case _:
        print("UNKNOWN VEHICLE")

# %%
CODE = input("ENTER DEPARTMENT CODE: ")

match CODE:
    case "101":
        print("IT")
    case "102":
        print("HR")
    case "103":
        print("FINANCE")
    case "104":
        print("MARKETING")
    case _:
        print("INVALID DEPARTMENT CODE")
# Out:
# FINANCE

# %%
CODE = input("ENTER COUNTRY CODE: ").upper()

match CODE:
    case "IN":
        print("INDIA")
    case "US":
        print("UNITED STATES")
    case "UK":
        print("UNITED KINGDOM")
    case "JP":
        print("JAPAN")
    case "AU":
        print("AUSTRALIA")
    case _:
        print("INVALID COUNTRY CODE")
# Out:
# INVALID COUNTRY CODE

# %%
MONTH = input("ENTER MONTH NAME: ").upper()

match MONTH:
    case "JANUARY" | "MARCH" | "MAY" | "JULY" | "AUGUST" | "OCTOBER" | "DECEMBER":
        print("31 DAYS")
    case "APRIL" | "JUNE" | "SEPTEMBER" | "NOVEMBER":
        print("30 DAYS")
    case "FEBRUARY":
        print("28 OR 29 DAYS")
    case _:
        print("INVALID MONTH")
# Out:
# 31 DAYS

# %%
PRIORITY = int(input("ENTER PRIORITY (1-5): "))

match PRIORITY:
    case 1:
        print("VERY HIGH PRIORITY")
    case 2:
        print("HIGH PRIORITY")
    case 3:
        print("MEDIUM PRIORITY")
    case 4:
        print("LOW PRIORITY")
    case 5:
        print("VERY LOW PRIORITY")
    case _:
        print("INVALID PRIORITY")
# Out:
# LOW PRIORITY

# %%
ROLE = input("ENTER USER ROLE: ").upper()

match ROLE:
    case "ADMIN":
        print("FULL ACCESS")
    case "TEACHER":
        print("TEACHER ACCESS")
    case "STUDENT":
        print("STUDENT ACCESS")
    case "GUEST":
        print("LIMITED ACCESS")
    case _:
        print("INVALID ROLE")
# Out:
# INVALID ROLE

# %%
PAYMENT = input("ENTER PAYMENT METHOD: ").upper()

match PAYMENT:
    case "CASH":
        print("CASH PAYMENT SELECTED")
    case "CARD":
        print("CARD PAYMENT SELECTED")
    case "UPI":
        print("UPI PAYMENT SELECTED")
    case "NETBANKING":
        print("NET BANKING PAYMENT SELECTED")
    case _:
        print("INVALID PAYMENT METHOD")
# Out:
# CASH PAYMENT SELECTED

# %%
NUMBER = int(input("ENTER NUMBER (1-3): "))

match NUMBER:
    case 1:
        print("ADDITION")
    case 2:
        print("SUBTRACTION")
    case 3:
        print("MULTIPLICATION")
    case _:
        print("INVALID NUMBER")
# Out:
# SUBTRACTION

# %%
VOWEL = input("ENTER A CHARACTER: ").lower()

match VOWEL:
    case "a" | "e" | "i" | "o" | "u":
        
        print("VOWEL")
    case _:
        print("NOT A VOWEL")
# Out:
# VOWEL

# %%
DAY = input("ENTER DAY: ").upper()

match DAY:
    case "SATURDAY" | "SUNDAY":
        print("WEEKEND")
    case _:
        print("WEEKDAY")
# Out:
# WEEKDAY

# %%
GRADE = input("ENTER GRADE: ").upper()

match GRADE:
    case "A" | "B":
        print("GOOD")
    case "C":
        print("AVERAGE")
    case "D":
        print("BELOW AVERAGE")
    case "F":
        print("FAIL")
    case _:
        print("INVALID GRADE")
# Out:
# GOOD

# %%
NUMBER = int(input("ENTER NUMBER: "))

match NUMBER:
    case 1 | 2 | 3:
        print("SMALL")
    case 4 | 5 | 6:
        print("MEDIUM")
    case 7 | 8 | 9 | 10:
        print("LARGE")
    case _:
        print("OUT OF RANGE")
# Out:
# MEDIUM

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1 | 2:
        print("OPEN")
    case 3:
        print("CLOSE")
    case 4:
        print("WAIT")
    case _:
        print("INVALID CHOICE")
# Out:
# OPEN MENU

# %%
ANSWER = input("DO YOU WANT TO CONTINUE? ")

match ANSWER:
    case "yes" | "y":
        print("CONTINUING")
    case _:
        print("INVALID RESPONSE")
# Out:
# CONTINUING

# %%
ANSWER = input("DO YOU WANT TO STOP? ")

match ANSWER:
    case "no" | "n":
        print("CONTINUING")
    case _:
        print("STOPPING")
# Out:
# CONTINUING

# %%
EXTENSION = input("FLOOR: ")

match EXTENSION:
    case "0" | "g" | "G":
        print("GROUND FLOOR")
    case "1":
        print("FIRST FLOOR")
    case "2":
        print("SECOND FLOOR")
    case "B" | "b" |"-1":
        print("BASEMENT")
    case _:
        print("UNKNOWN FILE TYPE")
# Out:
# BASEMENT

# %%
COMMAND = input("ENTER COMMAND: ").upper()

match COMMAND:
    case "START" | "RUN" | "EXECUTE":
        print("PROGRAM STARTED")
    case "STOP":
        print("PROGRAM STOPPED")
    case _:
        print("UNKNOWN COMMAND")
# Out:
# PROGRAM STARTED

# %%
NUMBER = int(input("ENTER NUMBER: "))

match NUMBER:
    case _ if NUMBER > 0:
        print("POSITIVE")
    case _ if NUMBER < 0:
        print("NEGATIVE")
    case _:
        print("ZERO")
# Out:
# POSITIVE

# %%
MARKS = int(input("ENTER MARKS: "))

match MARKS:
    case _ if MARKS > 100:
            print("INVALID MARKS")
    case _ if MARKS >= 90:
        print("A GRADE")
    case _ if MARKS >= 75:
        print("B GRADE")
    case _ if MARKS >= 50:
        print("C GRADE")
    case _:
        print("FAIL")
# Out:
# B GRADE

# %%
AGE = int(input("ENTER AGE: "))

match AGE:
    case _ if AGE < 13:
        print("CHILD")
    case _ if AGE < 20:
        print("TEENAGER")
    case _ if AGE < 60:
        print("ADULT")
    case _:
        print("SENIOR CITIZEN")
# Out:
# ADULT

# %%
SALARY = float(input("ENTER SALARY: "))

match SALARY:
    case _ if SALARY < 30000:
        print("LOW SALARY")
    case _ if SALARY < 70000:
        print("MEDIUM SALARY")
    case _:
        print("HIGH SALARY")
# Out:
# HIGH SALARY

# %%
TEMPERATURE = float(input("ENTER TEMPERATURE: "))

match TEMPERATURE:
    case _ if TEMPERATURE < 20:
        print("COLD")
    case _ if TEMPERATURE <= 30:
        print("NORMAL")
    case _:
        print("HOT")
# Out:
# NORMAL

# %%
NUMBER = int(input("ENTER NUMBER: "))

match NUMBER:
    case _ if 10 <= NUMBER <= 50:
        print("NUMBER IS WITHIN THE RANGE")
    case _:
        print("NUMBER IS OUTSIDE THE RANGE")
# Out:
# NUMBER IS WITHIN THE RANGE

# %%
ATTENDANCE = float(input("ENTER ATTENDANCE PERCENTAGE: "))

match ATTENDANCE:
    case _ if ATTENDANCE >= 75:
        print("ELIGIBLE")
    case _:
        print("NOT ELIGIBLE")
# Out:
# ELIGIBLE

# %%
AMOUNT = float(input("ENTER SHOPPING AMOUNT: "))

match AMOUNT:
    case _ if AMOUNT >= 10000:
        print("30% DISCOUNT")
    case _ if AMOUNT >= 5000:
        print("20% DISCOUNT")
    case _ if AMOUNT >= 2000:
        print("10% DISCOUNT")
    case _:
        print("NO DISCOUNT")
# Out:
# 30% DISCOUNT

# %%
SPEED = int(input("ENTER SPEED: "))

match SPEED:
    case _ if SPEED < 40:
        print("LOW SPEED")
    case _ if SPEED <= 80:
        print("NORMAL SPEED")
    case _:
        print("HIGH SPEED")
# Out:
# NORMAL SPEED

# %%
BALANCE = float(input("ENTER BANK BALANCE: "))

match BALANCE:
    case _ if BALANCE < 0:
        print("OVERDRAWN")
    case _ if BALANCE == 0:
        print("ZERO BALANCE")
    case _ if BALANCE < 10000:
        print("LOW BALANCE")
    case _:
        print("GOOD BALANCE")
# Out:
# LOW BALANCE

# %%
VALUES = (10, 20)

match VALUES:
    case (10, 20):
        print("MATCHED 10 AND 20")
    case _:
        print("NO MATCH")
# Out:
# MATCHED 10 AND 20

# %%
VALUES = [10, 20, 30]

match VALUES:
    case [a, b, c]:
        print("THREE VALUES")
        print(a, b, c)
    case _:
        print("NOT THREE VALUES")
# Out:
# THREE VALUES
# 10 20 30

# %%
DATE = (10, 9)

match DATE:
    case (day, month):
        print("DAY:", day)
        print("MONTH:", month)
# Out:
# DAY: 10
# MONTH: 9

# %%
ORDER = ("LAPTOP", 2)

match ORDER:
    case (product, quantity):
        print("PRODUCT:", product)
        print("QUANTITY:", quantity)
# Out:
# PRODUCT: LAPTOP
# QUANTITY: 2

# %%
USER = ("ARUN", "ADMIN")

match USER:
    case ("ARUN", "ADMIN"):
        print("ARUN", "HAS FULL ACCESS")
    case _:
        print("UNKNOWN USER")
# Out:
# ARUN HAS FULL ACCESS

# %%
SHAPE = ("CIRCLE", 10)

match SHAPE:
    case ("CIRCLE", radius):
        print("CIRCLE WITH RADIUS", radius)
    case ("SQUARE", side):
        print("SQUARE WITH SIDE", side)
    case ("RECTANGLE", length, width):
        print("RECTANGLE")
    case _:
        print("UNKNOWN SHAPE")
# Out:
# CIRCLE WITH RADIUS 10

# %%
DATA = ("ARUN", (25, "INDIA"))

match DATA:
    case (name, (age, country)):
        print("NAME:", name)
        print("AGE:", age)
        print("COUNTRY:", country)
# Out:
# NAME: ARUN
# AGE: 25
# COUNTRY: INDIA

# %%
DATA = ("ADD", 10, 20)

match DATA:
    case ("ADD", a, b):
        print(a + b)
    case ("SUBTRACT", a, b):
        print(a - b)
    case ("MULTIPLY", a, b):
        print(a * b)
    case ("DIVIDE", a, b):
        print(a / b)
    case _:
        print("INVALID OPERATION")
# Out:
# 30

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("PIZZA - ₹200")
    case 2:
        print("BURGER - ₹150")
    case 3:
        print("BIRYANI - ₹180")
    case 4:
        print("FRIED RICE - ₹120")
    case _:
        print("INVALID CHOICE")
# Out:
# BURGER - ₹150

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("DEPOSIT")
    case 2:
        print("WITHDRAWAL")
    case 3:
        print("CHECK BALANCE")
    case 4:
        print("EXIT")
    case _:
        print("INVALID CHOICE")
# Out:
# INVALID CHOICE

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("PROFILE")
    case 2:
        print("MARKS")
    case 3:
        print("ATTENDANCE")
    case 4:
        print("LOGOUT")
    case _:
        print("INVALID CHOICE")
# Out:
# ATTENDANCE

# %%
CATEGORY = input("ENTER CATEGORY (REGULAR, PREMIUM, VIP): ").upper()

match CATEGORY:
    case "REGULAR":
        print("REGULAR TICKET - ₹150")
    case "PREMIUM":
        print("PREMIUM TICKET - ₹250")
    case "VIP":
        print("VIP TICKET - ₹400")
    case _:
        print("INVALID CATEGORY")
# Out:
# VIP TICKET - ₹400

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("BOOK TICKET")
    case 2:
        print("CANCEL TICKET")
    case 3:
        print("CHECK BOOKING")
    case 4:
        print("EXIT")
    case _:
        print("INVALID CHOICE")
# Out:
# BOOK TICKET

# %%
PLAN = int(input("ENTER PLAN (1-4): "))

match PLAN:
    case 1:
        print("₹199 - 1GB/DAY")
    case 2:
        print("₹299 - 1.5GB/DAY")
    case 3:
        print("₹399 - 2GB/DAY")
    case 4:
        print("₹499 - 3GB/DAY")
    case _:
        print("INVALID PLAN")
# Out:
# ₹299 - 1.5GB/DAY

# %%
DEPARTMENT = input("ENTER DEPARTMENT: ").lower()

match DEPARTMENT:
    case "cardiology":
        print("CARDIOLOGY DEPARTMENT")
    case "neurology":
        print("NEUROLOGY DEPARTMENT")
    case "orthopedic":
        print("ORTHOPEDIC DEPARTMENT")
    case "pediatrics":
        print("PEDIATRICS DEPARTMENT")
    case _:
        print("INVALID DEPARTMENT")
# Out:
# CARDIOLOGY DEPARTMENT

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("BORROW BOOK")
    case 2:
        print("RETURN BOOK")
    case 3:
        print("SEARCH BOOK")
    case 4:
        print("EXIT")
    case _:
        print("INVALID CHOICE")
# Out:
# EXIT

# %%
VEHICLE = input("ENTER VEHICLE TYPE: ").lower()

match VEHICLE:
    case "bike":
        print("BIKE PARKING - ₹20")
    case "car":
        print("CAR PARKING - ₹50")
    case "bus":
        print("BUS PARKING - ₹100")
    case _:
        print("INVALID VEHICLE")
# Out:
# BIKE PARKING - ₹20

# %%
CLASS = input("ENTER CLASS (1A, 2A, 3A, SL): ").upper()

match CLASS:
    case "1A":
        print("FIRST AC")
    case "2A":
        print("SECOND AC")
    case "3A":
        print("THIRD AC")
    case "SL":
        print("SLEEPER CLASS")
    case _:
        print("INVALID CLASS")
# Out:
# FIRST AC

# %%
NUMBER1 = float(input("ENTER FIRST NUMBER: "))
OPERATOR = input("ENTER OPERATOR: ")
NUMBER2 = float(input("ENTER SECOND NUMBER: "))

match OPERATOR:
    case "+":
        print(NUMBER1 + NUMBER2)
    case "-":
        print(NUMBER1 - NUMBER2)
    case "*":
        print(NUMBER1 * NUMBER2)
    case "/":
        print(NUMBER1 / NUMBER2)
    case "%":
        print(NUMBER1 % NUMBER2)
    case "**":
        print(NUMBER1 ** NUMBER2)
    case _:
        print("INVALID OPERATOR")
# Out:
# 240.0

# %%
COMMAND = input("ENTER COMMAND: ").lower()

match COMMAND:
    case "add":
        print("ADD OPERATION")
    case "remove":
        print("REMOVE OPERATION")
    case "view":
        print("VIEW OPERATION")
    case "exit":
        print("PROGRAM EXITED")
    case _:
        print("INVALID COMMAND")
# Out:
# INVALID COMMAND

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("ADD ITEM TO CART")
    case 2:
        print("REMOVE ITEM FROM CART")
    case 3:
        print("VIEW CART")
    case 4:
        print("CHECKOUT")
    case _:
        print("INVALID CHOICE")
# Out:
# REMOVE ITEM FROM CART

# %%
FOOD = input("ENTER FOOD: ").lower()

match FOOD:
    case "pizza":
        print("PIZZA - ₹200")
    case "burger":
        print("BURGER - ₹150")
    case "biryani":
        print("BIRYANI - ₹180")
    case "noodles":
        print("NOODLES - ₹120")
    case "ice cream":
        print("ICE CREAM - ₹80")
    case _:
        print("FOOD NOT AVAILABLE")
# Out:
# FOOD NOT AVAILABLE

# %%
MARKS = int(input("ENTER MARKS: "))

match MARKS:
    case _ if MARKS >= 90:
        print("A GRADE")
    case _ if MARKS >= 75:
        print("B GRADE")
    case _ if MARKS >= 60:
        print("C GRADE")
    case _ if MARKS >= 50:
        print("D GRADE")
    case _:
        print("F GRADE")
# Out:
# C GRADE

# %%
CHOICE = int(input("ENTER CHOICE (1-4): "))

match CHOICE:
    case 1:
        print("CHECK BALANCE")
    case 2:
        print("WITHDRAW MONEY")
    case 3:
        print("DEPOSIT MONEY")
    case 4:
        print("EXIT")
    case _:
        print("INVALID CHOICE")
# Out:
# EXIT

# %%
WEATHER = input("ENTER WEATHER: ").lower()

match WEATHER:
    case "rainy":
        print("TAKE AN UMBRELLA")
    case "sunny":
        print("WEAR SUNGLASSES")
    case "cold":
        print("WEAR WARM CLOTHES")
    case "windy":
        print("BE CAREFUL OUTSIDE")
    case _:
        print("UNKNOWN WEATHER")
# Out:
# TAKE AN UMBRELLA

# %%
COMMAND = input("ENTER COMMAND: ").lower()

match COMMAND:
    case "open":
        print("FILE OPENED")
    case "read":
        print("READING FILE")
    case "write":
        print("WRITING TO FILE")
    case "close":
        print("FILE CLOSED")
    case _:
        print("INVALID COMMAND")
# Out:
# FILE OPENED

# %%
ISSUE = input("ENTER ISSUE: ").lower()

match ISSUE:
    case "payment":
        print("PAYMENT SUPPORT")
    case "delivery":
        print("DELIVERY SUPPORT")
    case "refund":
        print("REFUND SUPPORT")
    case "account":
        print("ACCOUNT SUPPORT")
    case _:
        print("OTHER SUPPORT")
# Out:
# REFUND SUPPORT

# %%
CHARACTER = input("CHOOSE CHARACTER: ").lower()

match CHARACTER:
    case "warrior":
        print("WARRIOR SELECTED")
    case "mage":
        print("MAGE SELECTED")
    case "archer":
        print("ARCHER SELECTED")
    case "assassin":
        print("ASSASSIN SELECTED")
    case _:
        print("INVALID CHARACTER")
# Out:
# ARCHER SELECTED
