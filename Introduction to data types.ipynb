# %%
id = int(100)
percentage = float(85.5)        
name = str("Dharun")    
aged_more_than_18 = bool(True)

# %%
print("id:",id)
print("percentage:",percentage)
print("name:",name)
print("aged_more_than_18:",aged_more_than_18)
# Out:
# id: <built-in function id>
# percentage: 85.5
# name: Dharun
# aged_more_than_18: True

# %%
id = 100
percentage = 85.5
name = "Dharun"
aged_more_than_18 = True

# %%
print("id:",id, type(id))
print("percentage:",percentage, type(percentage))
print("name:",name, type(name))
print("aged_more_than_18:",aged_more_than_18, type(aged_more_than_18))
# Out:
# id: 100 <class 'int'>
# percentage: 85.5 <class 'float'>
# name: Dharun <class 'str'>
# aged_more_than_18: True <class 'bool'>

# %%
print(type(25))
print(type(25.5))
print(type("25"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
number = "100"

# %%
print(number,type(number))
# Out:
# 100 <class 'str'>

# %%
number = 100

# %%
print(number,type(number))
# Out:
# 100 <class 'int'>

# %%
name = "Dharun"
age = 22
percentage = 85.5
student = True

# %%
print(type(name))
print(type(age))
print(type(percentage))
print(type(student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
