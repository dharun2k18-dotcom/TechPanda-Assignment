# %%
number = int(input("Enter a number: "))

result = "Even" if number % 2 == 0 else "Odd"

print(result)
# Out:
# Odd

# %%
number = int(input("Enter a number: "))

result = "Positive" if number > 0 else "Negative"

print(result)
# Out:
# Positive

# %%
number = int(input("Enter a number: "))

result = "Zero" if number == 0 else "Non-zero"

print(result)
# Out:
# Zero

# %%
age = int(input("Enter your age: "))

result = "Adult" if age >= 18 else "Minor"

print(result)
# Out:
# Minor

# %%
number = int(input("Enter a number: "))

result = "Greater than 50" if number > 50 else "50 or less"

print(result)
# Out:
# Greater than 50

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

result = a if a > b else b

print("Larger number:", result)
# Out:
# Larger number: 3

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

result = a if a < b else b

print("Smaller number:", result)
# Out:
# Smaller number: 2

# %%
mark = int(input("Enter your mark: "))

result = "Pass" if mark >= 40 else "Fail"

print(result)
# Out:
# Pass

# %%
number = int(input("Enter a number: "))

result = "Divisible by 5" if number % 5 == 0 else "Not divisible by 5"

print(result)
# Out:
# Divisible by 5

# %%
number = int(input("Enter a number: "))

result = "Multiple of 10" if number % 10 == 0 else "Not a multiple of 10"

print(result)
# Out:
# Multiple of 10

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

result = "Equal" if a == b else "Not Equal"

print(result)
# Out:
# Equal

# %%
age = int(input("Enter your age: "))

result = "Child" if age < 13 else "Teenager"

print(result)
# Out:
# Teenager

# %%
number = int(input("Enter a number: "))

result = "Positive Even" if number > 0 and number % 2 == 0 else "Not Positive Even"

print(result)
# Out:
# Not Positive Even

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

maximum = a if a > b else b

print("Maximum:", maximum)
# Out:
# Maximum: 76

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

largest = a if a > b and a > c else b if b > c else c

print("Largest:", largest)
# Out:
# Largest: 65

# %%
mark = int(input("Enter your mark: "))

result = "Pass" if mark >= 40 else "Fail"

print(result)
# Out:
# Pass

# %%
temperature = float(input("Enter temperature: "))

result = "Hot" if temperature > 30 else "Normal"

print(result)
# Out:
# Hot

# %%
salary = float(input("Enter your salary: "))

result = "High Salary" if salary >= 50000 else "Low Salary"

print(result)
# Out:
# Low Salary

# %%
number = int(input("Enter a number: "))

result = "Even and Positive" if number > 0 and number % 2 == 0 else "Not Even and Positive"

print(result)
# Out:
# Even and Positive

# %%
# 21. Yes

# %%
# 22. Odd

# %%
# 23. Minor

# %%
# 24. a

# %%
# 25. Fail

# %%
age = 20

result = "Eligible" if age >= 18 else "Not Eligible"

print(result)
# Out:
# Eligible

# %%
num = 7

result = "Even" if num % 2 == 0 else "Odd"

print(result)
# Out:
# Odd

# %%
a = 10
b = 20

result = a if a > b else b

print(result)
# Out:
# 20

# %%
marks = 75

result = "Pass" if marks >= 50 else "Fail"

print(result)
# Out:
# Pass

# %%
num = -5

result = "Positive" if num >= 0 else "Negative"

print(result)
# Out:
# Negative

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

largest = a if a > b and a > c else b if b > c else c

print("Largest:", largest)
# Out:
# Largest: 3

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

smallest = a if a < b and a < c else b if b < c else c

print("Smallest:", smallest)
# Out:
# Smallest: 1

# %%
number = int(input("Enter a number: "))

result = "Positive" if number > 0 else "Negative" if number < 0 else "Zero"

print(result)
# Out:
# Positive

# %%
marks = int(input("Enter your mark: "))

result = "Distinction" if marks >= 75 else "Pass" if marks >= 40 else "Fail"

print(result)
# Out:
# Fail

# %%
age = int(input("Enter your age: "))

result = "Child" if age < 13 else "Teenager" if age <= 19 else "Adult" if age < 60 else "Senior Citizen"

print(result)
# Out:
# Teenager
