# %%
name = "Dharun"
age = 25
city = "Nagercoil"

# %%
print(name)
print(age)
print(city)
# Out:
# Dharun
# 25
# Nagercoil

# %%
first_name = "Dharun"
last_name = "V S"

# %%
print(first_name, last_name)
# Out:
# Dharun V S

# %%
college = "TechPanda Academy"
course = "Data Engineering"
year = 2026

# %%
print(college)
print(course)
print(year)
# Out:
# TechPanda Academy
# Data Engineering
# 2026

# %%
number = 100
decimal = 25.5
language = "Python"
status = True

# %%
print(number)
print(decimal)
print(language)
print(status)
# Out:
# 100
# 25.5
# Python
# True

# %%
a = 10
b = 20

a, b = b, a

# %%
print(a)
print(b)
# Out:
# 20
# 10

# %%
salary = 25000

# %%
print("My salary is", salary)
# Out:
# My salary is 25000

# %%
a = 10
b = 20

sum = a + b

# %%
print(sum)
# Out:
# 30

# %%
name = "Python"

# %%
print(name)
print(name)
print(name)
print(name)
print(name)
# Out:
# Python
# Python
# Python
# Python
# Python
