# %%
number = "100"

# %%
number = int(number)

# %%
print(number)
print(type(number))
# Out:
# 100
# <class 'int'>

# %%
number = 50

# %%
number = float(number)

# %%
print(number)
print(type(number))
# Out:
# 50.0
# <class 'float'>

# %%
number = 100

# %%
number = str(number)

# %%
print(number)
print(type(number))
# Out:
# 100
# <class 'str'>

# %%
number = "25.75"

# %%
number = float(number)

# %%
print(number)
print(type(number))
# Out:
# 25.75
# <class 'float'>

# %%
a = input("Enter first number: ")
b = input("Enter second number: ")

a = int(a)
b = int(b)

sum = a + b

# %%
print("Sum:", sum)
# Out:
# Sum: 1131

# %%
age = input("Enter your age: ")

age = int(age)

# %%
print(age)
print(type(age))
# Out:
# 25
# <class 'int'>

# %%
number = float(input("Enter a decimal number: "))

number = int(number)

# %%
print(number)                                     # Entered 45.77 and recieved output as 45
print(type(number))
# Out:
# 45

# %%
number = int(float(input("Enter an integer: ")))


number = float(number)

# %%
print(number)                                      #Entered 57 and recieved output as 57.0
print(type(number))
# Out:
# 57.0
# <class 'float'>
